# %%
def ispisiIme():
    print("hej cao Marko")

print("hej hej")
# Out:
# hej hej

# %%
import pandas as pd
print(f"Pandas verzija: {pd.__version__}")

data = {
    'Proizvod': ['jabuke', 'Banane', 'Kivi'],
    'Prodaja' : [150,200,80],
    'Zalihe' : [50, 20, 100]
}

df = pd.DataFrame(data)

print(df.describe())
# Out:
# Pandas verzija: 3.0.1
#           Prodaja      Zalihe
# count    3.000000    3.000000
# mean   143.333333   56.666667
# std     60.277138   40.414519
# min     80.000000   20.000000
# 25%    115.000000   35.000000
# 50%    150.000000   50.000000
# 75%    175.000000   75.000000
# max    200.000000  100.000000
